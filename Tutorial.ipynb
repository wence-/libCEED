# %% [markdown]
# # libCEED tutorial
#
# This tutorial shows some examples of libCEED for efficient operator evaluations for the solutions of PDEs. For the purpose of separation of concerns, in these examples we use PETSc for mesh handling and time integration (when needed in the PDE).

# %%
# This is a Python code cell. 
# Every instruction in the cell that starts with ! is going to be interpreted and executed as a bash command.

# let's build libCEED:

! make -B
# Out:
# /bin/sh: 1: gfortran: not found
# /bin/sh: 1: gfortran: not found
# make: 'lib' with optional backends:
#           CC build/interface/ceed-fortran.o
#           CC build/interface/ceed-basis.o
#           CC build/interface/ceed-elemrestriction.o
#           CC build/interface/ceed-operator.o
#           CC build/interface/ceed-vector.o
#           CC build/interface/ceed.o
#           CC build/interface/ceed-tensor.o
#           CC build/interface/ceed-qfunction.o
#           CC build/interface/ceed-types.o
#           CC build/gallery/identity/ceed-identity.o
#           CC build/gallery/poisson3d/ceed-poisson3dapply.o
#           CC build/gallery/poisson3d/ceed-poisson3dbuild.o
#           CC build/gallery/mass1d/ceed-massapply.o
#           CC build/gallery/mass1d/ceed-mass1dbuild.o
#           CC build/gallery/mass2d/ceed-mass2dbuild.o
#           CC build/gallery/scale/ceed-scale.o
#           CC build/gallery/poisson1d/ceed-poisson1dapply.o
#           CC build/gallery/poisson1d/ceed-poisson1dbuild.o
#           CC build/gallery/mass3d/ceed-mass3dbuild.o
#           CC build/gallery/poisson2d/ceed-poisson2dapply.o
#           CC build/gallery/poisson2d/ceed-poisson2dbuild.o
#           CC build/backends/ref/ceed-ref-basis.o
#           CC build/backends/ref/ceed-ref-operator.o
#           CC build/backends/ref/ceed-ref-qfunction.o
#           CC build/backends/ref/ceed-ref-restriction.o
#           CC build/backends/ref/ceed-ref-tensor.o
#           CC build/backends/ref/ceed-ref-vector.o
#           CC build/backends/ref/ceed-ref.o
#           CC build/backends/blocked/ceed-blocked-operator.o
#           CC build/backends/blocked/ceed-blocked.o
#           CC build/backends/opt/ceed-opt-blocked.o
#           CC build/backends/opt/ceed-opt-operator.o
#           CC build/backends/opt/ceed-opt-serial.o
#         LINK lib/libceed.so

# %%
# Now let's build the examples that use PETSc, from the examples/petsc directory:

! make -B PETSC_DIR=/srv/conda/envs/notebook -C examples/petsc
# Out:
# make: Entering directory '/home/jovyan/examples/petsc'
# mpicc -std=c99 -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /srv/conda/envs/notebook/include -O3 -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /srv/conda/envs/notebook/include   -I/srv/conda/envs/notebook/include -I/home/jovyan/include -L/srv/conda/envs/notebook/lib -L/home/jovyan/lib  -Wl,-rpath,/srv/conda/envs/notebook/lib  -Wl,-rpath,/home/jovyan/lib  /home/jovyan/examples/petsc/area.c -o area \
#   -lpetsc -lceed -lm
# mpicc -std=c99 -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /srv/conda/envs/notebook/include -O3 -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /srv/conda/envs/notebook/include   -I/srv/conda/envs/notebook/include -I/home/jovyan/include -L/srv/conda/envs/notebook/lib -L/home/jovyan/lib  -Wl,-rpath,/srv/conda/envs/notebook/lib  -Wl,-rpath,/home/jovyan/lib  /home/jovyan/examples/petsc/bps.c -o bps \
#   -lpetsc -lceed -lm
# mpicc -std=c99 -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /srv/conda/envs/notebook/include -O3 -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /srv/conda/envs/notebook/include   -I/srv/conda/envs/notebook/include -I/home/jovyan/include -L/srv/conda/envs/notebook/lib -L/home/jovyan/lib  -Wl,-rpath,/srv/conda/envs/notebook/lib  -Wl,-rpath,/home/jovyan/lib  /home/jovyan/examples/petsc/bpsraw.c -o bpsraw \
#   -lpetsc -lceed -lm
# mpicc -std=c99 -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /srv/conda/envs/notebook/include -O3 -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /srv/conda/envs/notebook/include   -I/srv/conda/envs/notebook/include -I/home/jovyan/include -L/srv/conda/envs/notebook/lib -L/home/jovyan/lib  -Wl,-rpath,/srv/conda/envs/notebook/lib  -Wl,-rpath,/home/jovyan/lib  /home/jovyan/examples/petsc/bpssphere.c -o bpssphere \
#   -lpetsc -lceed -lm
# mpicc -std=c99 -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /srv/conda/envs/notebook/include -O3 -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /srv/conda/envs/notebook/include   -I/srv/conda/envs/notebook/include -I/home/jovyan/include -L/srv/conda/envs/notebook/lib -L/home/jovyan/lib  -Wl,-rpath,/srv/conda/envs/notebook/lib  -Wl,-rpath,/home/jovyan/lib  /home/jovyan/examples/petsc/multigrid.c -o multigrid \
#   -lpetsc -lceed -lm
# make: Leaving directory '/home/jovyan/examples/petsc'

# %%
# Link the executables from the current directory to make it easy to run below

! cp -sf examples/petsc/bpsraw .
! cp -sf examples/petsc/bps .
! cp -sf examples/petsc/bpssphere .
! cp -sf examples/petsc/area .
! cp -sf examples/petsc/multigrid .

# %% [markdown]
# ## BPs
#
# The Center for Efficient Exascale Discretizations (CEED), part of the Exascale Computing Project (ECP) uses Benchmark Problems (BPs) to test and compare the performance of high-order finite element implementations.

# %%
# Let's run bpsraw. This example uses a structured rectangular grid.

! ./bpsraw -ceed /cpu/self/ref/serial -problem bp3 -degree 1
# Out:
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   PETSc:
#     PETSc Vec Type                     : seq
#   libCEED:
#     libCEED Backend                    : /cpu/self/ref/serial
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 2
#     Number of 1D Quadrature Points (Q) : 3
#     Global nodes                       : 1331
#     Process Decomposition              : 1 1 1
#     Local Elements                     : 1000 = 10 10 10
#     Owned nodes                        : 1331 = 11 11 11
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : CONVERGED_RTOL
#     Total KSP Iterations               : 2
#     Final rnorm                        : 7.646897e-15
#   Performance:
#     Pointwise Error (max)              : 1.112075e-01
#     CG Solve Time                      : 0.0072521 (0.0072521) sec
#     DoFs/Sec in CG                     : 0.367066 (0.367066) million

# %%
# Let's run in parallel

! mpiexec -n 2 ./bpsraw -ceed /cpu/self/ref/serial -problem bp3 -degree 1
# Out:
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/ref/serial
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 2
#     Number of 1D Quadrature Points (Q) : 3
#     Global nodes                       : 2541
#     Process Decomposition              : 2 1 1
#     Local Elements                     : 1000 = 10 10 10
#     Owned nodes                        : 1210 = 10 11 11
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : CONVERGED_RTOL
#     Total KSP Iterations               : 2
#     Final rnorm                        : 8.189562e-15
#   Performance:
#     Pointwise Error (max)              : 1.091383e-01
#     CG Solve Time                      : 0.0102704 (0.00936765) sec
#     DoFs/Sec in CG                     : 0.49482 (0.542505) million

# %%
# Let's run it with a blocked backend

! mpiexec -n 2 ./bpsraw -ceed /cpu/self/ref/blocked -problem bp3 -degree 1
# Out:
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/ref/blocked
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 2
#     Number of 1D Quadrature Points (Q) : 3
#     Global nodes                       : 2541
#     Process Decomposition              : 2 1 1
#     Local Elements                     : 1000 = 10 10 10
#     Owned nodes                        : 1210 = 10 11 11
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : CONVERGED_RTOL
#     Total KSP Iterations               : 2
#     Final rnorm                        : 8.159318e-15
#   Performance:
#     Pointwise Error (max)              : 1.091383e-01
#     CG Solve Time                      : 0.00500435 (0.00356853) sec
#     DoFs/Sec in CG                     : 1.01552 (1.42411) million

# %% [markdown]
# ### Running a suite of BPs
# We can the `bps`, using unstructured meshes, in batch, so that the `mpiexec` is invoked only once and noise is minimized.

# %%
# Let's run bps. This example uses an unstructured grid

! mpiexec -n 4 ./bps -problem bp3 -degree 2,4,6       \
    -ceed /cpu/self/opt/serial,/cpu/self/opt/blocked  \
    -local_nodes 600,5000 | tee bps.log
# Out:
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/serial
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 3
#     Number of 1D Quadrature Points (Q) : 4
#     Global nodes                       : 1881
#     Local Elements                     : 71
#     Owned nodes                        : 367
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : CONVERGED_RTOL
#     Total KSP Iterations               : 8
#     Final rnorm                        : 8.888028e-12
#   Performance:
#     Pointwise Error (max)              : 6.605839e-03
#     CG Solve Time                      : 0.00806684 (0.00806538) sec
#     DoFs/Sec in CG                     : 1.86541 (1.86575) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/blocked
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 3
#     Number of 1D Quadrature Points (Q) : 4
#     Global nodes                       : 1881
#     Local Elements                     : 71
#     Owned nodes                        : 367
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : CONVERGED_RTOL
#     Total KSP Iterations               : 8
#     Final rnorm                        : 8.942880e-12
#   Performance:
#     Pointwise Error (max)              : 6.605839e-03
#     CG Solve Time                      : 0.00424198 (0.00423259) sec
#     DoFs/Sec in CG                     : 3.5474 (3.55527) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/serial
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 3
#     Number of 1D Quadrature Points (Q) : 4
#     Global nodes                       : 3971
#     Local Elements                     : 154
#     Owned nodes                        : 901
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : CONVERGED_RTOL
#     Total KSP Iterations               : 8
#     Final rnorm                        : 5.548705e-13
#   Performance:
#     Pointwise Error (max)              : 5.052368e-03
#     CG Solve Time                      : 0.100773 (0.100772) sec
#     DoFs/Sec in CG                     : 0.315245 (0.315247) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/blocked
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 3
#     Number of 1D Quadrature Points (Q) : 4
#     Global nodes                       : 3971
#     Local Elements                     : 154
#     Owned nodes                        : 901
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : CONVERGED_RTOL
#     Total KSP Iterations               : 8
#     Final rnorm                        : 5.521759e-13
#   Performance:
#     Pointwise Error (max)              : 5.052368e-03
#     CG Solve Time                      : 0.00640672 (0.00640576) sec
#     DoFs/Sec in CG                     : 4.95855 (4.95928) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/serial
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 3
#     Number of 1D Quadrature Points (Q) : 4
#     Global nodes                       : 8303
#     Local Elements                     : 296
#     Owned nodes                        : 1803
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : CONVERGED_RTOL
#     Total KSP Iterations               : 8
#     Final rnorm                        : 2.856864e-13
#   Performance:
#     Pointwise Error (max)              : 2.807439e-03
#     CG Solve Time                      : 0.0993918 (0.0993916) sec
#     DoFs/Sec in CG                     : 0.668304 (0.668306) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/blocked
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 3
#     Number of 1D Quadrature Points (Q) : 4
#     Global nodes                       : 8303
#     Local Elements                     : 296
#     Owned nodes                        : 1803
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : CONVERGED_RTOL
#     Total KSP Iterations               : 8
#     Final rnorm                        : 2.851841e-13
#   Performance:
#     Pointwise Error (max)              : 2.807439e-03
#     CG Solve Time                      : 0.0884574 (0.0884568) sec
#     DoFs/Sec in CG                     : 0.750915 (0.75092) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/serial
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 3
#     Number of 1D Quadrature Points (Q) : 4
#     Global nodes                       : 17081
#     Local Elements                     : 592
#     Owned nodes                        : 3915
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : CONVERGED_RTOL
#     Total KSP Iterations               : 8
#     Final rnorm                        : 1.371309e-12
#   Performance:
#     Pointwise Error (max)              : 1.468684e-03
#     CG Solve Time                      : 0.201018 (0.201011) sec
#     DoFs/Sec in CG                     : 0.679781 (0.679805) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/blocked
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 3
#     Number of 1D Quadrature Points (Q) : 4
#     Global nodes                       : 17081
#     Local Elements                     : 592
#     Owned nodes                        : 3915
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 5
#     Final rnorm                        : 1.192211e-01
#   Performance:
#     Pointwise Error (max)              : 3.181853e-02
#     CG Solve Time                      : 0.0157553 (0.0157447) sec
#     DoFs/Sec in CG                     : 5.42072 (5.42436) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/serial
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 3
#     Number of 1D Quadrature Points (Q) : 4
#     Global nodes                       : 35061
#     Local Elements                     : 1198
#     Owned nodes                        : 8091
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 5
#     Final rnorm                        : 1.058624e-01
#   Performance:
#     Pointwise Error (max)              : 2.246205e-02
#     CG Solve Time                      : 0.302356 (0.302347) sec
#     DoFs/Sec in CG                     : 0.579797 (0.579813) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/blocked
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 3
#     Number of 1D Quadrature Points (Q) : 4
#     Global nodes                       : 35061
#     Local Elements                     : 1198
#     Owned nodes                        : 8091
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 5
#     Final rnorm                        : 1.058624e-01
#   Performance:
#     Pointwise Error (max)              : 2.246205e-02
#     CG Solve Time                      : 0.184187 (0.184186) sec
#     DoFs/Sec in CG                     : 0.951777 (0.951781) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/serial
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 5
#     Number of 1D Quadrature Points (Q) : 6
#     Global nodes                       : 1995
#     Local Elements                     : 10
#     Owned nodes                        : 427
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 20
#     Final rnorm                        : 6.638039e-04
#   Performance:
#     Pointwise Error (max)              : 1.316153e-03
#     CG Solve Time                      : 0.0960665 (0.0960654) sec
#     DoFs/Sec in CG                     : 0.415337 (0.415342) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/blocked
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 5
#     Number of 1D Quadrature Points (Q) : 6
#     Global nodes                       : 1995
#     Local Elements                     : 10
#     Owned nodes                        : 427
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 5
#     Final rnorm                        : 6.069956e-01
#   Performance:
#     Pointwise Error (max)              : 5.590094e-01
#     CG Solve Time                      : 0.0021567 (0.00214715) sec
#     DoFs/Sec in CG                     : 4.62511 (4.64569) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/serial
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 5
#     Number of 1D Quadrature Points (Q) : 6
#     Global nodes                       : 3971
#     Local Elements                     : 19
#     Owned nodes                        : 855
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 20
#     Final rnorm                        : 2.929325e-04
#   Performance:
#     Pointwise Error (max)              : 4.810323e-04
#     CG Solve Time                      : 0.09173 (0.0915375) sec
#     DoFs/Sec in CG                     : 0.865802 (0.867623) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/blocked
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 5
#     Number of 1D Quadrature Points (Q) : 6
#     Global nodes                       : 3971
#     Local Elements                     : 19
#     Owned nodes                        : 855
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 20
#     Final rnorm                        : 2.929325e-04
#   Performance:
#     Pointwise Error (max)              : 4.810323e-04
#     CG Solve Time                      : 0.0123665 (0.0123619) sec
#     DoFs/Sec in CG                     : 6.42219 (6.42459) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/serial
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 5
#     Number of 1D Quadrature Points (Q) : 6
#     Global nodes                       : 8303
#     Local Elements                     : 36
#     Owned nodes                        : 1771
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 20
#     Final rnorm                        : 9.841747e-05
#   Performance:
#     Pointwise Error (max)              : 1.702084e-04
#     CG Solve Time                      : 0.181239 (0.181237) sec
#     DoFs/Sec in CG                     : 0.91625 (0.916257) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/blocked
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 5
#     Number of 1D Quadrature Points (Q) : 6
#     Global nodes                       : 8303
#     Local Elements                     : 36
#     Owned nodes                        : 1771
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 20
#     Final rnorm                        : 9.841747e-05
#   Performance:
#     Pointwise Error (max)              : 1.702084e-04
#     CG Solve Time                      : 0.0921194 (0.0921183) sec
#     DoFs/Sec in CG                     : 1.80266 (1.80268) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/serial
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 5
#     Number of 1D Quadrature Points (Q) : 6
#     Global nodes                       : 17043
#     Local Elements                     : 71
#     Owned nodes                        : 3687
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 5
#     Final rnorm                        : 7.378670e-01
#   Performance:
#     Pointwise Error (max)              : 5.625665e-01
#     CG Solve Time                      : 0.0182442 (0.0182333) sec
#     DoFs/Sec in CG                     : 4.67081 (4.67359) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/blocked
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 5
#     Number of 1D Quadrature Points (Q) : 6
#     Global nodes                       : 17043
#     Local Elements                     : 71
#     Owned nodes                        : 3687
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 20
#     Final rnorm                        : 1.476003e-03
#   Performance:
#     Pointwise Error (max)              : 3.690650e-04
#     CG Solve Time                      : 0.191245 (0.191245) sec
#     DoFs/Sec in CG                     : 1.78232 (1.78232) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/serial
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 5
#     Number of 1D Quadrature Points (Q) : 6
#     Global nodes                       : 34983
#     Local Elements                     : 154
#     Owned nodes                        : 8467
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 20
#     Final rnorm                        : 6.048913e-04
#   Performance:
#     Pointwise Error (max)              : 2.080824e-04
#     CG Solve Time                      : 0.496133 (0.496127) sec
#     DoFs/Sec in CG                     : 1.41023 (1.41024) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/blocked
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 5
#     Number of 1D Quadrature Points (Q) : 6
#     Global nodes                       : 34983
#     Local Elements                     : 154
#     Owned nodes                        : 8467
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 20
#     Final rnorm                        : 6.048913e-04
#   Performance:
#     Pointwise Error (max)              : 2.080824e-04
#     CG Solve Time                      : 0.382582 (0.382582) sec
#     DoFs/Sec in CG                     : 1.82878 (1.82879) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/serial
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 7
#     Number of 1D Quadrature Points (Q) : 8
#     Global nodes                       : 2057
#     Local Elements                     : 3
#     Owned nodes                        : 425
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 20
#     Final rnorm                        : 2.078309e-06
#   Performance:
#     Pointwise Error (max)              : 6.946935e-06
#     CG Solve Time                      : 0.00887903 (0.00887716) sec
#     DoFs/Sec in CG                     : 4.63339 (4.63437) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/blocked
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 7
#     Number of 1D Quadrature Points (Q) : 8
#     Global nodes                       : 2057
#     Local Elements                     : 3
#     Owned nodes                        : 425
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 20
#     Final rnorm                        : 2.078309e-06
#   Performance:
#     Pointwise Error (max)              : 6.946935e-06
#     CG Solve Time                      : 0.0885009 (0.0885003) sec
#     DoFs/Sec in CG                     : 0.464854 (0.464857) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/serial
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 7
#     Number of 1D Quadrature Points (Q) : 8
#     Global nodes                       : 4301
#     Local Elements                     : 6
#     Owned nodes                        : 935
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 20
#     Final rnorm                        : 2.061470e-03
#   Performance:
#     Pointwise Error (max)              : 9.757418e-04
#     CG Solve Time                      : 0.110362 (0.110361) sec
#     DoFs/Sec in CG                     : 0.779438 (0.779445) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/blocked
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 7
#     Number of 1D Quadrature Points (Q) : 8
#     Global nodes                       : 4301
#     Local Elements                     : 6
#     Owned nodes                        : 935
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 20
#     Final rnorm                        : 2.061470e-03
#   Performance:
#     Pointwise Error (max)              : 9.757418e-04
#     CG Solve Time                      : 0.0898234 (0.0898227) sec
#     DoFs/Sec in CG                     : 0.957657 (0.957665) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/serial
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 7
#     Number of 1D Quadrature Points (Q) : 8
#     Global nodes                       : 8381
#     Local Elements                     : 11
#     Owned nodes                        : 1745
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 20
#     Final rnorm                        : 4.755627e-02
#   Performance:
#     Pointwise Error (max)              : 1.920471e-02
#     CG Solve Time                      : 0.101142 (0.101141) sec
#     DoFs/Sec in CG                     : 1.65728 (1.65729) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/blocked
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 7
#     Number of 1D Quadrature Points (Q) : 8
#     Global nodes                       : 8381
#     Local Elements                     : 11
#     Owned nodes                        : 1745
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 20
#     Final rnorm                        : 4.755627e-02
#   Performance:
#     Pointwise Error (max)              : 1.920471e-02
#     CG Solve Time                      : 0.101324 (0.101323) sec
#     DoFs/Sec in CG                     : 1.6543 (1.65431) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/serial
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 7
#     Number of 1D Quadrature Points (Q) : 8
#     Global nodes                       : 17255
#     Local Elements                     : 23
#     Owned nodes                        : 4085
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 20
#     Final rnorm                        : 4.704178e-02
#   Performance:
#     Pointwise Error (max)              : 1.867513e-02
#     CG Solve Time                      : 0.302005 (0.302004) sec
#     DoFs/Sec in CG                     : 1.1427 (1.1427) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/blocked
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 7
#     Number of 1D Quadrature Points (Q) : 8
#     Global nodes                       : 17255
#     Local Elements                     : 23
#     Owned nodes                        : 4085
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 20
#     Final rnorm                        : 4.704178e-02
#   Performance:
#     Pointwise Error (max)              : 1.867513e-02
#     CG Solve Time                      : 0.188663 (0.18865) sec
#     DoFs/Sec in CG                     : 1.82918 (1.82931) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/serial
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 7
#     Number of 1D Quadrature Points (Q) : 8
#     Global nodes                       : 35525
#     Local Elements                     : 45
#     Owned nodes                        : 8381
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 20
#     Final rnorm                        : 9.861636e-03
#   Performance:
#     Pointwise Error (max)              : 2.508315e-03
#     CG Solve Time                      : 0.481455 (0.481453) sec
#     DoFs/Sec in CG                     : 1.47574 (1.47574) million
#
# -- CEED Benchmark Problem 3 -- libCEED + PETSc --
#   MPI:
#     Hostname                           : jupyter-ceed-2dlibceed-2dk4wrq43m
#     Total ranks                        : 4
#     Ranks per compute node             : 4
#   PETSc:
#     PETSc Vec Type                     : mpi
#   libCEED:
#     libCEED Backend                    : /cpu/self/opt/blocked
#     libCEED Backend MemType            : host
#     libCEED User Requested MemType     : none
#   Mesh:
#     Number of 1D Basis Nodes (P)       : 7
#     Number of 1D Quadrature Points (Q) : 8
#     Global nodes                       : 35525
#     Local Elements                     : 45
#     Owned nodes                        : 8381
#     DoF per node                       : 1
#   KSP:
#     KSP Type                           : cg
#     KSP Convergence                    : DIVERGED_ITS
#     Total KSP Iterations               : 5
#     Final rnorm                        : 5.506114e-01
#   Performance:
#     Pointwise Error (max)              : 7.426691e-01
#     CG Solve Time                      : 0.0165353 (0.0165338) sec
#     DoFs/Sec in CG                     : 10.7422 (10.7431) million

# %%
! ls
# Out:
# area		     build		 include	 python
# AUTHORS		     ceed.pc.template	 interface	 README.rst
# azure-pipelines.yml  CODE_OF_CONDUCT.md  Jenkinsfile	 requirements-gpu.txt
# backends	     CONTRIBUTING.md	 lib		 requirements-test.txt
# benchmarks	     doc		 LICENSE	 requirements.txt
# bps		     Doxyfile		 Makefile	 setup.py
# bps.log		     environment.yml	 multigrid	 tests
# bpsraw		     examples		 NOTICE		 Tutorial.ipynb
# bpssphere	     gallery		 pyproject.toml

# %% [markdown]
# ### Plotting the BPs performance summary
# You can open a new notebook by clicking on the File -> Open menu. Navigate to the `benchmarks` directory and select the `postprocess_altair.ipynb` notebook. This will open a Jupyter Notebook that uses `altair`, a package for interactive visualization.
